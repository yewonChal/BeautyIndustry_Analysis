# %%
import pandas as pd

review = pd.read_csv('data_all(전처리완료).csv', encoding='utf-8')
review.head()
# Out:
#    브랜드  평점      피부타입     피부고민       자극도  \
# 0  닥터지   4  복합성에 좋아요  진정에 좋아요     보통이에요
# 1  닥터지   5   건성에 좋아요  진정에 좋아요  자극없이 순해요
# 2  닥터지   5  복합성에 좋아요  진정에 좋아요     보통이에요
# 3  닥터지   5   건성에 좋아요  보습에 좋아요  자극없이 순해요
# 4  닥터지   4  복합성에 좋아요  보습에 좋아요  자극없이 순해요
#
#                                                   리뷰
# 0             컵 받고싶어서 샀어요 크림은 튜브형태러 내줄 생각은 없는건지 궁금해요
# 1  닥터지는 사계절 내내 잘 사용하고잇어요   물론 건성피부에게 겨울에는 얼굴당김잇어서...
# 2   아빠 사드렸는데 좋아해요 근데 바르는게 쫌 별로긴 한데 투브타입으로 나오면 더 좋을 듯
# 3  국민 수분 크림이라 그런지 모든 피부타입에도 잘 맞으면서 무난한 아이템이에요 당황이...
# 4   여름용 수분크림이 필요해서 산 제품이에요  가격은 세일가로 28800원 했어요사실...

# %%
filtered_data = data[(data['평점'] == 2) | (data['평점'] == 1)]

output_file_path_filtered = 'data_all(부정).csv'
filtered_data.to_csv(output_file_path_filtered, index=False)

output_file_path_filtered
# Out:
# 'data_all(부정).csv'

# %%
review_부정 = pd.read_csv('data_all(부정).csv', encoding='utf-8')
review_부정
# Out:
#      브랜드  평점      피부타입        피부고민       자극도  \
# 0    아비브   1   지성에 좋아요  주름/미백에 좋아요  자극이 느껴져요
# 1    아비브   1   건성에 좋아요  주름/미백에 좋아요  자극이 느껴져요
# 2    아비브   1   지성에 좋아요     진정에 좋아요  자극없이 순해요
# 3    아비브   2   지성에 좋아요  주름/미백에 좋아요  자극이 느껴져요
# 4    아비브   2  복합성에 좋아요     진정에 좋아요  자극이 느껴져요
# ..   ...  ..       ...         ...       ...
# 200  CNP   2   건성에 좋아요     보습에 좋아요     보통이에요
# 201  CNP   2   건성에 좋아요     보습에 좋아요     보통이에요
# 202  CNP   1   건성에 좋아요     보습에 좋아요  자극이 느껴져요
# 203  CNP   1  복합성에 좋아요     보습에 좋아요     보통이에요
# 204  CNP   2   건성에 좋아요     보습에 좋아요     보통이에요
#
#                                                     리뷰
# 0    와 이게 수분크림이 맞나요 바르고 피부 뒤집어져도 나한테만 안맞겠거니 리뷰 안쓰는데...
# 1    트러블 나요  여러번 테스트 해봤는데도 건성 수부지 복합성 이예요 지성인 남자친구도...
# 2    수분크림인데 바르고 시간이 조금만 지나도 수분감이 거의 안느껴지고 제형도 별로에요 ...
# 3    지성용 보습제 같습니다 제가 민감건성이긴 한데 수분크림중에 이렇게 안 촉촉한 제품은...
# 4    생각보다 별로였어요 바르면 얼굴이 붉어지는게 저한테는 안맞는 성분이 있나봅니다  가...
# ..                                                 ...
# ...

# %%
filtered_data = data[(data['평점'] == 3) | (data['평점'] == 4) | (data['평점'] == 5)]

output_file_path_filtered = 'data_all(긍정).csv'
filtered_data.to_csv(output_file_path_filtered, index=False)

output_file_path_filtered
# Out:
# 'data_all(긍정).csv'

# %%
review_긍정 = pd.read_csv('data_all(긍정).csv', encoding='utf-8')
review_긍정
# Out:
#       브랜드  평점      피부타입     피부고민       자극도  \
# 0     닥터지   4  복합성에 좋아요  진정에 좋아요     보통이에요
# 1     닥터지   5   건성에 좋아요  진정에 좋아요  자극없이 순해요
# 2     닥터지   5  복합성에 좋아요  진정에 좋아요     보통이에요
# 3     닥터지   5   건성에 좋아요  보습에 좋아요  자극없이 순해요
# 4     닥터지   4  복합성에 좋아요  보습에 좋아요  자극없이 순해요
# ...   ...  ..       ...      ...       ...
# 5285  CNP   5   건성에 좋아요  보습에 좋아요  자극없이 순해요
# 5286  CNP   5  복합성에 좋아요  보습에 좋아요  자극없이 순해요
# 5287  CNP   5   건성에 좋아요  보습에 좋아요  자극없이 순해요
# 5288  CNP   5  복합성에 좋아요  진정에 좋아요     보통이에요
# 5289  CNP   5  복합성에 좋아요  보습에 좋아요  자극없이 순해요
#
#                                                      리뷰
# 0                컵 받고싶어서 샀어요 크림은 튜브형태러 내줄 생각은 없는건지 궁금해요
# 1     닥터지는 사계절 내내 잘 사용하고잇어요   물론 건성피부에게 겨울에는 얼굴당김잇어서...
# 2      아빠 사드렸는데 좋아해요 근데 바르는게 쫌 별로긴 한데 투브타입으로 나오면 더 좋을 듯
# 3     국민 수분 크림이라 그런지 모든 피부타입에도 잘 맞으면서 무난한 아이템이에요 당황이...
# 4      여름용 수분크림이 필요해서 산 제품이에요  가격은 세일가로 28800원 했어요사실...
# ...                                                 ...
# ...
